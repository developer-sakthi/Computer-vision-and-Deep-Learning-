# %%
intial_weight = 0.5

learning_rate = 0.1

gradient = 0.2

# %%
# TASK 1 - compute updated weight

new_weight = intial_weight - learning_rate * gradient 
print(new_weight)
# Out:
# 0.48

# %%
# TASK 2 - compute updated weight with new learning rate
learning_rate = 1.0

new_weight = intial_weight - learning_rate * gradient 
print(new_weight)
# Out:
# 0.3
